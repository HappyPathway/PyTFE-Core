# %%
import random
import os
import json
import string
import hvac

from tfe.session import TFESession
from tfe.organization import Organization
from tfe.workspace import Workspace, VCSRepo
from tfe.oauth_client import OauthClient


def personal_access_token():
    client = hvac.Client(url=os.environ.get('VAULT_ADDR'), token=os.environ.get("VAULT_TOKEN"))
    client = hvac.Client(
        url=os.environ.get('VAULT_ADDR'), 
        token=os.environ.get("VAULT_TOKEN")
    )
    return client.read("secret/credentials/github").get("data").get("personal_access_token")


timeout = random.randint(100,600)
rand_string = ''.join(random.choices(string.ascii_uppercase + string.digits, k=24))
session = TFESession("https://app.terraform.io", os.environ.get("ATLAS_TOKEN"))
org = Organization("Darnold-{0}".format(rand_string))
org.logger.setLevel("ERROR")
org.email = "darnold@hashicorp.com"
org.session_remember = timeout
org.session_timeout = timeout
org.collaborator_auth_policy = "two_factor_mandatory"
org.create()


oauth = OauthClient()
oauth.logger.setLevel("DEBUG")
oauth.organization = org
oauth.service_provider = "github"
oauth.personal_access_token = personal_access_token()
oauth.http_url = "https://github.com"
oauth.api_url = "https://api.github.com"
oauth.logger.debug(
    "Oauth Create: {0}".format(str(oauth.create().id))
)

vcs_repo = VCSRepo()
vcs_repo.identifier = "HappyPathway/aws-network-hosts"
vcs_repo.oauth_token_id = oauth.token
vcs_repo.branch = "master"

ws = Workspace()
ws.logger.setLevel("DEBUG")
ws.organization = org
ws.vcs_repo = vcs_repo
ws.name = "AWSNetworks{0}".format(rand_string)
ws.logger.debug(
    "Workspace Create: {0}".format(str(ws.create()))
)
print(
    ws.render()
)
ws2 = Workspace(ws.id, organization=org, name="AWSNetworks{0}".format(rand_string))
assert(ws2.vcs_repo.identifier == "HappyPathway/aws-network-hosts")

org.delete()
# Out:
# 2018-10-12 22:55:56,470 com.happypathway.tfe.Organization: 404 Client Error: Not Found for url: https://app.terraform.io/api/v2/organizations/Darnold-ZGV7BU99GZ2I74MKRK1ZYT47
# 2018-10-12 22:55:56,472 com.happypathway.tfe.Organization: 'NoneType' object has no attribute 'get'
# 2018-10-12 22:55:56,987 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: name
# 2018-10-12 22:55:56,988 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: created-at
# 2018-10-12 22:55:56,988 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: session-timeout
# 2018-10-12 22:55:56,989 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: session-remember
# 2018-10-12 22:55:56,991 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: collaborator-auth-policy
# 2018-10-12 22:55:56,992 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: enterprise-plan
# 2018-10-12 22:55:56,993 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: permissions
# 2018-10-12 22:55:56,995 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: trial-expires-at
# 2018-10-12 22:55:56,996 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: fair-run-queuing-enabled
# 2018-10-12 22:55:56,999 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: saml-enabled
# 2018-10-12 22:55:57,000 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: owners-team-saml-role-id
# 2018-10-12 22:55:57,001 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: slack-connected
# 2018-10-12 22:55:57,002 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: slack-enabled
# 2018-10-12 22:55:57,004 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: two-factor-conformant
# 2018-10-12 22:55:57,178 com.happypathway.tfe.OauthClient: service_provider: github
# 2018-10-12 22:55:57,180 com.happypathway.tfe.OauthClient: http_url: https://github.com
# 2018-10-12 22:55:57,181 com.happypathway.tfe.OauthClient: api_url: https://api.github.com
# 2018-10-12 22:55:57,183 com.happypathway.tfe.OauthClient: personal_access_token: 7146087b2696d09b74ac70789bae47245111e24c
# 2018-10-12 22:55:57,187 com.happypathway.tfe.OauthClient: {
#     "data":{
#         "attributes":{
#             "api-url":"https://api.github.com",
#             "http-url":"https://github.com",
#             "oauth-token-string":"7146087b2696d09b74ac70789bae47245111e24c",
#             "service-provider":"github"
#         },
#         "type":"oauth-clients"
#     }
# }
# 2018-10-12 22:55:57,668 com.happypathway.tfe.OauthClient: Oauth Create: oc-SYwKo9siYS1p5qcb
# 2018-10-12 22:55:58,035 com.happypathway.tfe.Workspace: name: AWSNetworksZGV7BU99GZ2I74MKRK1ZYT47
# 2018-10-12 22:55:58,037 com.happypathway.tfe.Workspace: vcs_repo: <tfe.workspace.VCSRepo object at 0x10b1b3f28>
# 2018-10-12 22:55:58,038 com.happypathway.tfe.Workspace: terraform_version: 0.11.8
# 2018-10-12 22:55:58,039 com.happypathway.tfe.Workspace: working_directory: None
# 2018-10-12 22:55:58,041 com.happypathway.tfe.Workspace: organization: Darnold-ZGV7BU99GZ2I74MKRK1ZYT47
# 2018-10-12 22:55:58,044 com.happypathway.tfe.Workspace: {
#     "data":{
#         "attributes":{
#             "name":"AWSNetworksZGV7BU99GZ2I74MKRK1ZYT47",
#             "terraform_version":"0.11.8",
#             "vcs-repo":{
#                 "branch":"master",
#                 "identifier":"HappyPathway/aws-network-hosts",
#                 "oauth-token-id":"ot-MjZXCABST6MaNLV5"
#             }
#         }
#     },
#     "type":"workspaces"
# }
# 2018-10-12 22:55:59,843 com.happypathway.tfe.Workspace: Workspace Create: <tfe.workspace.Workspace object at 0x10b2b8390>
# resource "tfe_workspace" "AWSNetworksZGV7BU99GZ2I74MKRK1ZYT47" {
#     name = "AWSNetworksZGV7BU99GZ2I74MKRK1ZYT47"
#     organization = "Darnold-ZGV7BU99GZ2I74MKRK1ZYT47"
#
#     terraform_version = "0.11.8"
#
#
#     vcs_repo = {
#         identifier = "HappyPathway/aws-network-hosts"
#
#         branch = "master"
#
#         oauth_token_id = "ot-MjZXCABST6MaNLV5"
#         ingress_submodules = None
#     }
#
# }
# 2018-10-12 22:56:01,365 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: name
# 2018-10-12 22:56:01,366 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: created-at
# 2018-10-12 22:56:01,367 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: session-timeout
# 2018-10-12 22:56:01,369 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: session-remember
# 2018-10-12 22:56:01,370 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: collaborator-auth-policy
# 2018-10-12 22:56:01,373 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: enterprise-plan
# 2018-10-12 22:56:01,374 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: permissions
# 2018-10-12 22:56:01,375 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: trial-expires-at
# 2018-10-12 22:56:01,376 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: fair-run-queuing-enabled
# 2018-10-12 22:56:01,376 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: saml-enabled
# 2018-10-12 22:56:01,377 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: owners-team-saml-role-id
# 2018-10-12 22:56:01,378 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: slack-connected
# 2018-10-12 22:56:01,378 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: slack-enabled
# 2018-10-12 22:56:01,379 com.happypathway.tfe.Organization: OrganizationValidator: does not have attribute: two-factor-conformant

# %%
import random
import os
import json
import string
import hvac

from tfe.session import TFESession
from tfe.organization import Organization
from tfe.workspace import Workspace, VCSRepo
from tfe.oauth_client import OauthClient

session = TFESession("https://app.terraform.io", os.environ.get("ATLAS_TOKEN"))
ws = Workspace(organization="Darnold-Hashicorp", name="VaultPolicies")
# Out:
# <tfe.run.Run object at 0x1093545f8>
# None
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-1e2dab44026c> in <module>()
#      22 )
#      23 print(
# ---> 24     ws.current_state.current()
#      25 )
#
# ~/git/PyTFE/tfe/state.py in current(self)
#     102         url = "{0}/api/v2//workspaces/{1}/current-state-version".format(
#     103             self.base_url,
# --> 104             self.workspace
#     105         )
#     106         resp = TFESession.get(url).json()
#
# AttributeError: 'State' object has no attribute 'workspace'
